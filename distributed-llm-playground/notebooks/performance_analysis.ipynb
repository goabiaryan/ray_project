# %% [markdown]
# # Performance analysis — Distributed LLM Playground
#
# Fill tables from `load_test/run_bench.py`, Locust UI exports, and Nsight summaries. See `report_template.md` for the narrative structure.

# %%
import pandas as pd

rows = [
    {"run": "A", "preset": "tiny_single", "p50_s": None, "p99_s": None, "rps": None, "tok_per_s": None},
    {"run": "B", "preset": "tiny_dp", "p50_s": None, "p99_s": None, "rps": None, "tok_per_s": None},
]
df = pd.DataFrame(rows)
df
